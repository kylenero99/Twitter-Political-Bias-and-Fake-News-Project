# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ted_cruz_gw = pd.read_json("tedcruztweets-congress115-congress16.json", lines=True)
ted_cruz_gw
# Out:
#                     created_at                   id               id_str  \
# 0    2019-02-05 21:41:26+00:00  1092901033523728384  1092901033523728384
# 1    2019-02-06 18:23:50+00:00  1093213694866145280  1093213694866145280
# 2    2019-02-06 23:28:56+00:00  1093290475317092352  1093290475317092352
# 3    2019-02-07 15:49:21+00:00  1093537207758016512  1093537207758016512
# 4    2019-02-07 22:55:11+00:00  1093644370698534912  1093644370698534912
# ...                        ...                  ...                  ...
# 6692 2020-01-22 23:07:14+00:00  1220120770006933505  1220120770006933504
# 6693 2020-01-23 01:11:11+00:00  1220151960390770693  1220151960390770688
# 6694 2020-01-22 21:54:38+00:00  1220102495642562563  1220102495642562560
# 6695 2020-01-23 15:25:11+00:00  1220366877647626242  1220366877647626240
# 6696 2020-01-23 00:17:07+00:00  1220138356530720768  1220138356530720768
#
#                                               full_text  truncated  \
# ...

# %%
ted_cruz_tweets_text_list = ted_cruz_gw["full_text"].tolist()
ted_cruz_hashtags = []

for tweet in ted_cruz_tweets_text_list:
    words = tweet.split(' ')
    for word in words:
        if len(word) > 0 and word[0] == "#":
            ted_cruz_hashtags.append(word)

ted_cruz_hashtags
# Out:
# ['#TermLimitsNow:',
#  '#termlimits',
#  '#CPAC2019:',
#  '#RaiderPower',
#  '#MarchMadness',
#  '#WreckEm',
#  '#RaiderPower',
#  '#FinalFour\n\n🔴#WreckEm⚫️',
#  '#SicEm',
#  '#RaiderPower',
#  '#WreckEmTech',
#  '#FinalF…',
#  '#GunsUp',
#  '#1',
#  '#TexasTech',
#  '#BestPlaces',
#  '#hspa',
#  '#hispolitica',
#  '#earma…',
#  '#WuhanCo…',
#  '#RadicalAndExtreme',
#  '#TCOT',
#  '#PJNET',
#  '#EpsteinCoverup',
#  '#Brexit',
#  '#Verdict',
#  '#Verdict:',
#  '#Verdict',
#  '#Brexit',
#  '#VERDICT…',
#  '#ICYMI:',
#  '#COVID19.…',
#  '#StaySafe',
#  '#Verdict',
#  '#Coronavirus,',
#  '#Verdict',
#  '#CoronaVirus',
#  '#WeWillMakeItThroughTogether',
#  '#Dream',
#  '#coronavirus',
#  '#ELCHAPOAct',
#  '#CPAC2019',
#  '#WhatMakesAmeri…',
#  '#CPAC2019',
#  '#TexasIndependenceDay!',
#  '#Texas',
#  '#BestPlaces',
#  '#TruthIsPowerful',
#  '#ArmedForcesDay',
#  '#LoveIsStrongerThanHate',
#  '#education',
#  '#news',
#  '#LemonadeFreedom',
#  '#education',
#  '#news',
#  '#education',
# ...

# %%
ted_cruz_hashtags_as_df = pd.DataFrame(ted_cruz_hashtags, columns=["Hashtag"])
ted_cruz_hashtags_frequency = ted_cruz_hashtags_as_df.groupby("Hashtag").size().reset_index(name='counts').sort_values("counts", ascending=False)
ted_cruz_hashtags_frequency.head(20)
# Out:
#                      Hashtag  counts
# 693                   #TXSen     490
# 409            #KeepTexasRed     376
# 190                #CruzCrew     209
# 147              #ChooseCruz     135
# 200           #CruzToVictory     115
# 791                 #Verdict      51
# 756            #ToughAsTexas      49
# 45            #AloneTogether      44
# 196               #CruzCrew:      38
# 415           #KeepTexasRed!      31
# 433            #KimmelvsCruz      25
# 426           #KeepTexasRed:      25
# 965                   #txsen      21
# 697          #TXSenateDebate      21
# 731             #TexasDebate      20
# 12                       #2A      17
# 164  #CombatCOVID19Challenge      16
# 961                  #txlege      16
# 826                 #WeCruzN      16
# 727                   #Texas      15

# %%
n=4
plt.bar(ted_cruz_hashtags_frequency['Hashtag'][:n], ted_cruz_hashtags_frequency['counts'][:n])
# Out:
# <BarContainer object of 4 artists>
